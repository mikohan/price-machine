# %%
from data.models import Supplier

# %%
suplier = Supplier.objects.first()
print(supplier)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Disk/Projects/PriceMachine/venv/lib/python3.9/site-packages/django/db/backends/base/base.py:282, in BaseDatabaseWrapper.ensure_connection(self)
#     281 with self.wrap_database_errors:
# --> 282     self.connect()
#
# File ~/Disk/Projects/PriceMachine/venv/lib/python3.9/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File ~/Disk/Projects/PriceMachine/venv/lib/python3.9/site-packages/django/db/backends/base/base.py:263, in BaseDatabaseWrapper.connect(self)
#     262 conn_params = self.get_connection_params()
# --> 263 self.connection = self.get_new_connection(conn_params)
#     264 self.set_autocommit(self.settings_dict["AUTOCOMMIT"])
#
# ...
